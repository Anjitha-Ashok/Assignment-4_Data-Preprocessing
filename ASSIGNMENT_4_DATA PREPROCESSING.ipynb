# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### Load the dataset into python environment

# %%
data = pd.read_csv(r"C:\Users\Hp\Downloads\titanic_dataset.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### Make ‘PassengerId’ as the index column

# %%
data1 = data.set_index('PassengerId')
data1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### Check the basic details of the dataset

# %%
data1.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data1.tail()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
data1.shape
# Out:
# (891, 11)

# %%
data1.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data1.info()         # It shows a error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-aabd94be135e> in <module>
# ----> 1 data1.info()         # It shows a error
#
# E:\Anaconda\lib\site-packages\pandas\core\frame.py in info(self, verbose, buf, max_cols, memory_usage, null_counts)
#    2503                         self.index._is_memory_usage_qualified()):
#    2504                     size_qualifier = '+'
# -> 2505             mem_usage = self.memory_usage(index=True, deep=deep).sum()
#    2506             lines.append("memory usage: {mem}\n".format(
#    2507                 mem=_sizeof_fmt(mem_usage, size_qualifier)))
#
# E:\Anaconda\lib\site-packages\pandas\core\frame.py in memory_usage(self, index, deep)
#    2597         if index:
#    2598             result = Series(self.index.memory_usage(deep=deep),
# -> 2599                             index=['Index']).append(result)
# ...

# %%
data1.describe()      # This code also shows a error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-0f14cbecedcc> in <module>
# ----> 1 data1.describe()      # This code also shows a error
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude)
#    9791         elif (include is None) and (exclude is None):
#    9792             # when some numerics are found, keep only numerics
# -> 9793             data = self.select_dtypes(include=[np.number])
#    9794             if len(data.columns) == 0:
#    9795                 data = self
#
# E:\Anaconda\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3324         # the "union" of the logic of case 1 and case 2:
#    3325         # we get the included and excluded, and return their logical and
# -> 3326         include_these = Series(not bool(include), index=self.columns)
# ...

# %%
data1.info
# Out:
# <bound method DataFrame.info of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# ...

# %%
data1.describe
# Out:
# <bound method NDFrame.describe of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# ...

# %% [markdown]
# ### Question 4

# %% [markdown]
# #### Fill in all the missing values present in all the columns in the dataset

# %%
data1.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
data1.isna().sum()/data.shape[0] * 100
# Out:
# Survived     0.000000
# Pclass       0.000000
# Name         0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Ticket       0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
plt.hist(data1['Age'])
plt.show()

# %%
Age_mean = data1['Age'].mean()
Age_mean
# Out:
# 29.69911764705882

# %%
data1['Age']=data1['Age'].fillna(Age_mean)   # Age is filled with the mean value

# %%
data1.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# Since the 77 percent of valuse are missing in the case of Cabin, let's drop the variable.

# %%
data2 = data1.drop(['Cabin'], axis=1)

# %%
data2.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    2
# dtype: int64

# %%
# Since there is only two missing values for the column 'Embarked', let's drop the rows with null values in that column.

# %%
data3 = data2.dropna()

# %%
data3.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# ### Question 5

# %% [markdown]
# #### Check and handle outliers in at least 3 columns in the dataset

# %%
data3.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### Removing outliers from SibSp

# %%
plt.boxplot(data3['SibSp'])
plt.show()

# %%
data4 = data3[data3['SibSp']<2.5]

# %%
plt.boxplot(data4['SibSp'])
plt.show()

# %% [markdown]
# #### Removing outliers from Fare

# %%
plt.boxplot(data4['Fare'])
plt.show()

# %%
data4.shape
# Out:
# (843, 10)

# %%
Q1 = data4['Fare'].quantile(0.25)
Q1
# Out:
# 7.8958

# %%
Q3 = data4['Fare'].quantile(0.75)
Q3
# Out:
# 29.7

# %%
IQR = Q3-Q1
IQR
# Out:
# 21.804199999999998

# %%
LB = Q1 - (1.5*IQR)
LB
# Out:
# -24.810499999999998

# %%
UB = Q3 + (1.5*IQR)
UB
# Out:
# 62.4063

# %%
data5 = data4[data4['Fare']<UB]

# %%
data5.shape
# Out:
# (736, 10)

# %% [markdown]
# #### Removing outliers from Age

# %%
plt.boxplot(data5['Age'])
plt.show()

# %%
data5.shape
# Out:
# (736, 10)

# %%
Q1 = data5['Age'].quantile(0.25)
Q1
# Out:
# 23.0

# %%
Q3 = data5['Age'].quantile(0.75)
Q3
# Out:
# 34.125

# %%
IQR = Q3-Q1
IQR
# Out:
# 11.125

# %%
LB = Q1 - (1.5*IQR)
LB
# Out:
# 6.3125

# %%
UB = Q3 + (1.5*IQR)
UB
# Out:
# 50.8125

# %%
data6 = data5[data5['Age']<UB]

# %%
data7 = data6[data6['Age']>LB]

# %%
data7.shape
# Out:
# (658, 10)

# %% [markdown]
# ### Question 6

# %% [markdown]
# #### Do min max scaling on the feature set

# %%
data7.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Embarked     object
# dtype: object

# %%
data8 = data7.drop(['Name'], axis=1)

# %%
data8.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Embarked     object
# dtype: object

# %%
data9 = pd.get_dummies(data8, columns = ['Sex','Embarked'])

# %%
data9.dtypes
# Out:
# Survived        int64
# Pclass          int64
# Age           float64
# SibSp           int64
# Parch           int64
# Ticket         object
# Fare          float64
# Sex_female      uint8
# Sex_male        uint8
# Embarked_C      uint8
# Embarked_Q      uint8
# Embarked_S      uint8
# dtype: object

# %%
data10 = data9.drop(['Ticket'],axis=1)

# %% [markdown]
# #### Min Max Scaling

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.DataFrame(data = data10,
                 columns=data10.columns)

# %%
X = data10.drop('Survived', axis=1)
y = data10['Survived']
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.25,
                                                    random_state=42)

X_train.shape, X_test.shape
# Out:
# ((493, 10), (165, 10))

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
scaler.data_max_
# Out:
# array([ 3.    , 50.    ,  2.    ,  6.    , 57.9792,  1.    ,  1.    ,
#         1.    ,  1.    ,  1.    ])

# %%
scaler.min_
# Out:
# array([-0.5       , -0.19047619,  0.        ,  0.        ,  0.        ,
#         0.        ,  0.        ,  0.        ,  0.        ,  0.        ])

# %%
scaler.data_range_
# Out:
# array([ 2.    , 42.    ,  2.    ,  6.    , 57.9792,  1.    ,  1.    ,
#         1.    ,  1.    ,  1.    ])

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
